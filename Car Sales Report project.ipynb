# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\hp\Downloads\archive (1)\Car Sales.xlsx - car_data.csv")

# %%
df
# Out:
#              Car_id        Date Customer Name  Gender  Annual Income  \
# 0      C_CND_000001    1/2/2022     Geraldine    Male          13500
# 1      C_CND_000002    1/2/2022           Gia    Male        1480000
# 2      C_CND_000003    1/2/2022        Gianna    Male        1035000
# 3      C_CND_000004    1/2/2022       Giselle    Male          13500
# 4      C_CND_000005    1/2/2022         Grace    Male        1465000
# ...             ...         ...           ...     ...            ...
# 23901  C_CND_023902  12/31/2023        Martin    Male          13500
# 23902  C_CND_023903  12/31/2023         Jimmy  Female         900000
# 23903  C_CND_023904  12/31/2023          Emma    Male         705000
# 23904  C_CND_023905  12/31/2023      Victoire    Male          13500
# 23905  C_CND_023906  12/31/2023       Donovan    Male        1225000
#
#                                Dealer_Name    Company       Model  \
# 0      Buddy Storbeck's Diesel Service Inc       Ford  Expedition
# ...

# %% [markdown]
# unique valuse in a company

# %%
df['Company'].unique()
# Out:
# array(['Ford', 'Dodge', 'Cadillac', 'Toyota', 'Acura', 'Mitsubishi',
#        'Chevrolet', 'Nissan', 'Mercury', 'BMW', 'Chrysler', 'Subaru',
#        'Hyundai', 'Honda', 'Infiniti', 'Audi', 'Porsche', 'Volkswagen',
#        'Buick', 'Saturn', 'Mercedes-B', 'Jaguar', 'Volvo', 'Pontiac',
#        'Lincoln', 'Oldsmobile', 'Lexus', 'Plymouth', 'Saab', 'Jeep'],
#       dtype=object)

# %%
df['Date'].agg(['min','max'])
# Out:
# min    1/10/2022
# max     9/9/2023
# Name: Date, dtype: object

# %% [markdown]
# #_it shows the starting date and nthe ending date of the data sets

# %% [markdown]
# find which gender is more

# %%
df['Gender'].sum
# Out:
# <bound method Series.sum of 0          Male
# 1          Male
# 2          Male
# 3          Male
# 4          Male
#           ...
# 23901      Male
# 23902    Female
# 23903      Male
# 23904      Male
# 23905      Male
# Name: Gender, Length: 23906, dtype: object>

# %%
df.describe()
# Out:
#        Annual Income     Price ($)         Phone
# count   2.390600e+04  23906.000000  2.390600e+04
# mean    8.308403e+05  28090.247846  7.497741e+06
# std     7.200064e+05  14788.687608  8.674920e+05
# min     1.008000e+04   1200.000000  6.000101e+06
# 25%     3.860000e+05  18001.000000  6.746495e+06
# 50%     7.350000e+05  23000.000000  7.496198e+06
# 75%     1.175750e+06  34000.000000  8.248146e+06
# max     1.120000e+07  85800.000000  8.999579e+06

# %% [markdown]
# it shows the statistc represends in the data frame
# _annual income and price just avoid phone

# %% [markdown]
# #find the null valuse on the data set

# %%
df.info
# Out:
# <bound method DataFrame.info of              Car_id        Date Customer Name  Gender  Annual Income  \
# 0      C_CND_000001    1/2/2022     Geraldine    Male          13500
# 1      C_CND_000002    1/2/2022           Gia    Male        1480000
# 2      C_CND_000003    1/2/2022        Gianna    Male        1035000
# 3      C_CND_000004    1/2/2022       Giselle    Male          13500
# 4      C_CND_000005    1/2/2022         Grace    Male        1465000
# ...             ...         ...           ...     ...            ...
# 23901  C_CND_023902  12/31/2023        Martin    Male          13500
# 23902  C_CND_023903  12/31/2023         Jimmy  Female         900000
# 23903  C_CND_023904  12/31/2023          Emma    Male         705000
# 23904  C_CND_023905  12/31/2023      Victoire    Male          13500
# 23905  C_CND_023906  12/31/2023       Donovan    Male        1225000
#
#                                Dealer_Name    Company       Model  \
# ...

# %% [markdown]
# largest income in a data sets

# %%
df['Annual Income'].nlargest()
# Out:
# 14026    11200000
# 15675     8000000
# 6150      7650000
# 9996      6800000
# 22407     6600000
# Name: Annual Income, dtype: int64

# %% [markdown]
# first 7 datas on the data set

# %%
df.head(7)
# Out:
#          Car_id      Date Customer Name Gender  Annual Income  \
# 0  C_CND_000001  1/2/2022     Geraldine   Male          13500
# 1  C_CND_000002  1/2/2022           Gia   Male        1480000
# 2  C_CND_000003  1/2/2022        Gianna   Male        1035000
# 3  C_CND_000004  1/2/2022       Giselle   Male          13500
# 4  C_CND_000005  1/2/2022         Grace   Male        1465000
# 5  C_CND_000006  1/2/2022     Guadalupe   Male         850000
# 6  C_CND_000007  1/2/2022        Hailey   Male        1600000
#
#                            Dealer_Name     Company       Model  \
# 0  Buddy Storbeck's Diesel Service Inc        Ford  Expedition
# 1                     C & M Motors Inc       Dodge     Durango
# 2                          Capitol KIA    Cadillac    Eldorado
# 3               Chrysler of Tri-Cities      Toyota      Celica
# 4                    Chrysler Plymouth       Acura          TL
# 5                        Classic Chevy  Mitsubishi    Diamante
# ...

# %% [markdown]
# rename the colum annual income to annual revenue

# %%
df.rename(columns={'Annual Income':'Annual Revenue'})
# Out:
#              Car_id        Date Customer Name  Gender  Annual Revenue  \
# 0      C_CND_000001    1/2/2022     Geraldine    Male           13500
# 1      C_CND_000002    1/2/2022           Gia    Male         1480000
# 2      C_CND_000003    1/2/2022        Gianna    Male         1035000
# 3      C_CND_000004    1/2/2022       Giselle    Male           13500
# 4      C_CND_000005    1/2/2022         Grace    Male         1465000
# ...             ...         ...           ...     ...             ...
# 23901  C_CND_023902  12/31/2023        Martin    Male           13500
# 23902  C_CND_023903  12/31/2023         Jimmy  Female          900000
# 23903  C_CND_023904  12/31/2023          Emma    Male          705000
# 23904  C_CND_023905  12/31/2023      Victoire    Male           13500
# 23905  C_CND_023906  12/31/2023       Donovan    Male         1225000
#
#                                Dealer_Name    Company       Model  \
# ...

# %%
most_selldcar=df['Company'].value_counts().head(10)

# %%
sns.barplot(x=most_selldcar.index,y=most_selldcar.values,color='g')
plt.xticks(rotation=90)
plt.title('Leading 10 Car selling companies on 2022 to 2023')
plt.show()

# %%
-in this barplot x-axis represents the company and the y-axis represents the number of cars

    Chevrolet sells most cars -dodge is the second place -Nisan in the 10th position

# %%
sns.barplot(x=df['Company'],y=df['Price ($)'],palette='inferno')
plt.xticks(rotation=90)
plt.grid(axis='y')
plt.grid(axis='x')
fontx={'family' : 'serif','color':'red','size':15   }
plt.title('Car Price Comparison Among Leading Brands',fontdict=fontx)
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_32812\2885235301.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['Company'],y=df['Price ($)'],palette='inferno')

# %% [markdown]
# in this barplot x-axis represents the company and the y-axis represents the price of cars
# #-the most expensive car is a Cadillac
# #-the most affordable car company is Hyundai

# %% [markdown]
# which company sell more cars on 2022

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df['Year']=df['Date'].dt.year

# %%
df
# Out:
#              Car_id       Date Customer Name  Gender  Annual Income  \
# 0      C_CND_000001 2022-01-02     Geraldine    Male          13500
# 1      C_CND_000002 2022-01-02           Gia    Male        1480000
# 2      C_CND_000003 2022-01-02        Gianna    Male        1035000
# 3      C_CND_000004 2022-01-02       Giselle    Male          13500
# 4      C_CND_000005 2022-01-02         Grace    Male        1465000
# ...             ...        ...           ...     ...            ...
# 23901  C_CND_023902 2023-12-31        Martin    Male          13500
# 23902  C_CND_023903 2023-12-31         Jimmy  Female         900000
# 23903  C_CND_023904 2023-12-31          Emma    Male         705000
# 23904  C_CND_023905 2023-12-31      Victoire    Male          13500
# 23905  C_CND_023906 2023-12-31       Donovan    Male        1225000
#
#                                Dealer_Name    Company       Model  \
# 0      Buddy Storbeck's Diesel Service Inc       Ford  Expedition
# ...

# %% [markdown]
# _

# %%
df[df['Year']==2023]
# Out:
#              Car_id       Date Customer Name  Gender  Annual Income  \
# 10645  C_CND_010646 2023-01-02          Owen    Male         563000
# 10646  C_CND_010647 2023-01-02       Patrick    Male        1014000
# 10647  C_CND_010648 2023-01-02       William    Male         483000
# 10648  C_CND_010649 2023-01-02         Wyatt    Male          13500
# 10649  C_CND_010650 2023-01-02      Izabella    Male         281000
# ...             ...        ...           ...     ...            ...
# 23901  C_CND_023902 2023-12-31        Martin    Male          13500
# 23902  C_CND_023903 2023-12-31         Jimmy  Female         900000
# 23903  C_CND_023904 2023-12-31          Emma    Male         705000
# 23904  C_CND_023905 2023-12-31      Victoire    Male          13500
# 23905  C_CND_023906 2023-12-31       Donovan    Male        1225000
#
#                              Dealer_Name     Company      Model  \
# 10645                 Diehl Motor CO Inc        Ford      Focus
# ...

# %%
df2023 = df[df['Year'] == 2023]

# %%
df2022 = df[df['Year'] == 2022]

# %%
df2023
# Out:
#              Car_id       Date Customer Name  Gender  Annual Income  \
# 10645  C_CND_010646 2023-01-02          Owen    Male         563000
# 10646  C_CND_010647 2023-01-02       Patrick    Male        1014000
# 10647  C_CND_010648 2023-01-02       William    Male         483000
# 10648  C_CND_010649 2023-01-02         Wyatt    Male          13500
# 10649  C_CND_010650 2023-01-02      Izabella    Male         281000
# ...             ...        ...           ...     ...            ...
# 23901  C_CND_023902 2023-12-31        Martin    Male          13500
# 23902  C_CND_023903 2023-12-31         Jimmy  Female         900000
# 23903  C_CND_023904 2023-12-31          Emma    Male         705000
# 23904  C_CND_023905 2023-12-31      Victoire    Male          13500
# 23905  C_CND_023906 2023-12-31       Donovan    Male        1225000
#
#                              Dealer_Name     Company      Model  \
# 10645                 Diehl Motor CO Inc        Ford      Focus
# ...

# %%
sns.countplot(x=df2023['Company'],palette='Set3')
plt.xticks(rotation=90)
plt.title('YEARLY TREND 2023')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_30644\2354908532.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df2023['Company'],palette='Set3')
# Text(0.5, 1.0, 'YEARLY TREND 2023')

# %% [markdown]
# in this yearly trend, Chevrolet sells most of its cars
# -this year Saab and Jaguar leas selling car

# %%
df2022['Company'].value_counts().head()
# Out:
# Company
# Chevrolet     776
# Ford          728
# Dodge         722
# Volkswagen    615
# Mitsubishi    572
# Name: count, dtype: int64

# %%
sns.countplot(df2022['Company'],palette='PRGn')
plt.xticks(rotation=90)
plt.title('YEARLY TREND 2022')
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_30644\293347841.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df2022['Company'],palette='PRGn')

# %% [markdown]
# #_In this yearly trend Chevrolet sells most of its cars
# #_Ford is the second-largest seller

# %%
corr=df.corr(numeric_only=True)

# %%
corr
# Out:
#                Annual Income  Price ($)     Phone      Year
# Annual Income       1.000000   0.012065 -0.000351 -0.031406
# Price ($)           0.012065   1.000000 -0.000493 -0.007511
# Phone              -0.000351  -0.000493  1.000000  0.006815
# Year               -0.031406  -0.007511  0.006815  1.000000

# %%
df
# Out:
#              Car_id        Date Customer Name  Gender  Annual Income  \
# 0      C_CND_000001    1/2/2022     Geraldine    Male          13500
# 1      C_CND_000002    1/2/2022           Gia    Male        1480000
# 2      C_CND_000003    1/2/2022        Gianna    Male        1035000
# 3      C_CND_000004    1/2/2022       Giselle    Male          13500
# 4      C_CND_000005    1/2/2022         Grace    Male        1465000
# ...             ...         ...           ...     ...            ...
# 23901  C_CND_023902  12/31/2023        Martin    Male          13500
# 23902  C_CND_023903  12/31/2023         Jimmy  Female         900000
# 23903  C_CND_023904  12/31/2023          Emma    Male         705000
# 23904  C_CND_023905  12/31/2023      Victoire    Male          13500
# 23905  C_CND_023906  12/31/2023       Donovan    Male        1225000
#
#                                Dealer_Name    Company       Model  \
# 0      Buddy Storbeck's Diesel Service Inc       Ford  Expedition
# ...

# %%
body=df['Body Style'].value_counts()

# %%
body
# Out:
# Body Style
# SUV          6374
# Hatchback    6128
# Sedan        4488
# Passenger    3945
# Hardtop      2971
# Name: count, dtype: int64

# %%
x=body.index
y=body.values
e=[0.3,0,0,0,0.2]
plt.pie(y,labels=x, shadow=True,autopct='%1.1f%%',explode=e)
plt.legend(bbox_to_anchor=(1,1),title='Body Style')
plt.title('Most popular Body Style')
plt.show()

# %% [markdown]
# _.in this pie charte shows the most popular body style is SUV 26.7% and Hatchback 25.6%.
# _.the least sold car type is a Hardtop

# %%
df['Dealer_Name'].value_counts().head()
# Out:
# Dealer_Name
# Progressive Shippers Cooperative Association No    1318
# Rabun Used Car Sales                               1313
# Race Car Help                                      1253
# Saab-Belle Dodge                                   1251
# Star Enterprises Inc                               1249
# Name: count, dtype: int64

# %%
sns.lineplot(x=df['Price ($)'],y=df['Annual Income'],hue=df['Gender'])
plt.xticks(rotation=90)
plt.title('Relationship Between Income and price of Gender')
plt.show()

# %% [markdown]
# #_In this line plot x-axis represents the Price and the y-axis represents the annual income of the customer
# #_ The higher-income male buys the most expensive car

# %%
df['Model'].value_counts()
# Out:
# Model
# Diamante         418
# Silhouette       411
# Prizm            411
# Passat           391
# Ram Pickup       383
#                 ...
# Mirage            19
# Alero             18
# RX300             15
# Avalon            15
# Sebring Conv.     10
# Name: count, Length: 154, dtype: int64

# %%
df['Company'].value_counts()
# Out:
# Company
# Chevrolet     1819
# Dodge         1671
# Ford          1614
# Volkswagen    1333
# Mercedes-B    1285
# Mitsubishi    1277
# Chrysler      1120
# Oldsmobile    1111
# Toyota        1110
# Nissan         886
# Mercury        874
# Lexus          802
# Pontiac        796
# BMW            790
# Volvo          789
# Honda          708
# Acura          689
# Cadillac       652
# Plymouth       617
# Saturn         586
# Lincoln        492
# Audi           468
# Buick          439
# Subaru         405
# Jeep           363
# Porsche        361
# Hyundai        264
# Saab           210
# Infiniti       195
# Jaguar         180
# Name: count, dtype: int64

# %%
sns.barplot(x=df['Model'].head(10),y=df['Price ($)'],palette='inferno')
plt.xticks(rotation=90)
plt.title('price and models')
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_30644\76547465.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['Model'].head(10),y=df['Price ($)'],palette='inferno')

# %%
df['Engine'].value_counts()
# Out:
# Engine
# DoubleÂ Overhead Camshaft    12571
# Overhead Camshaft            11335
# Name: count, dtype: int64

# %%
import plotly.express as px

# %%
sns.boxplot(data = df,x ='Body Style', y = 'Price ($)',palette='Accent' )
plt.title('Price Distribution by Body Style')
plt.xlabel('body_style')
plt.ylabel('price_($)')
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_17428\2150537033.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data = df,x ='Body Style', y = 'Price ($)',palette='Accent' )

# %% [markdown]
# in this boxplot shows the price distribution by body style
# _.SUV ,, and hatchback have almost the same price distribution

# %%
y=df['Price ($)']
x=df['Gender']
sns.barplot (data=df,x='Price ($)',y='Gender',palette='Set2')
plt.title('Price Distribution by Gender')
plt.xlabel('price_($)')
plt.ylabel('Gender')
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_29916\4037727715.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot (data=df,x='Price ($)',y='Gender',palette='Set2')

# %% [markdown]
# it shows gender and price Distribution in this boxplot male and female bothe are same price Distribution

# %%
sns.countplot(data=df,x='Color',palette = 'flare')
plt.title('Most Popular Color')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_17428\100016816.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df,x='Color',palette = 'flare')
# Text(0.5, 1.0, 'Most Popular Color')

# %% [markdown]
# in this plot shows the most popular color is pale white
